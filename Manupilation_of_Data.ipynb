# %% [markdown]
# Manupilation of Data to handle various issue in dataframe

# %%
import pandas as pd
iris = pd.read_csv('C:/Users/5530/OneDrive/Desktop/Data_Analytics/Data-Analytics/Terrorist_data/terrorismData.csv')
df = iris.copy()

# %%
df.Year.is_unique
help=df.City.drop_duplicates()
help_df =help.to_frame(name='city')
help_df.isnull().sum()
# help_df.sum()
# Out:
# city    0
# dtype: int64

# %%
help_year=df[df.Year>2000][['Year','Region']]
# help_df_year=help_year.to_frame(name='Year_above_2000')
help_year
# Out:
#         Year                      Region
# 71650   2001               South America
# 71651   2001  Middle East & North Africa
# 71652   2001               South America
# 71653   2001  Middle East & North Africa
# 71654   2001  Middle East & North Africa
# ...      ...                         ...
# 181686  2017          Sub-Saharan Africa
# 181687  2017  Middle East & North Africa
# 181688  2017              Southeast Asia
# 181689  2017                  South Asia
# 181690  2017              Southeast Asia
#
# [110041 rows x 2 columns]

# %%
help_year[help_year.Region=='South America'].describe()
help_year.loc[1816]=[2017,'India']
# help_year.tail(10)
# print(len(df.columns))
help_year.reset_index(drop=True,inplace=True)
help_year.index
# df.drop('Region',axis=1)
df.drop('Day',axis=1)
# Out:
#         Year  Month             Country            State  \
# 0       1970      7  Dominican Republic              NaN
# 1       1970      0              Mexico          Federal
# 2       1970      1         Philippines           Tarlac
# 3       1970      1              Greece           Attica
# 4       1970      1               Japan          Fukouka
# ...      ...    ...                 ...              ...
# 181686  2017     12             Somalia  Middle Shebelle
# 181687  2017     12               Syria         Lattakia
# 181688  2017     12         Philippines      Maguindanao
# 181689  2017     12               India          Manipur
# 181690  2017     12         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# ...

# %%
df['new_lats'] = df['Latitude']-df['Longitude']
df.tail()
# Out:
#         Year  Month  Day      Country            State  \
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded            Target  \
# 181686                   Armed Assault     1.0      2.0        Checkpoint
# ...
