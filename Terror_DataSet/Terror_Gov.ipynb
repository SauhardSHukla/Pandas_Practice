# %% [markdown]
# ###### Problem statement
# Given file "terrorismData.csv"
#
# It is an open-source database including information on terrorist attacks around the world from 1970 through 2017. This dataset includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period
#
#
# ##### Problem Statement :
# There was formation of new government in India on 26 May 2014. So current government's span is from 26th May 2014 to current. Find out two things from this period-
#
# 1. Total number of attacks done in this period in India. Find this count as integer.
# 2. Which Terrorist group was most active in this period in India. Most active means, group which has done maximum number of attacks.
# ##### 3.Ignore the Unknown group.
# ##### Output Format :
# TotalAttacks MostActiveTerroristGroup

# %%
import pandas as pd
import numpy as np
terror = pd.read_csv('C:/Users/5530/OneDrive/Desktop/Data_Analytics/Data-Analytics/Terrorist_data/terrorismData.csv')
df = terror.copy()
# df.head(3)
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
#
#             City   Latitude   Longitude                   AttackType  Killed  \
# 0  Santo Domingo  18.456792  -69.951164                Assassination     1.0
# 1    Mexico city  19.371887  -99.086624  Hostage Taking (Kidnapping)     0.0
# 2        Unknown  15.478598  120.599741                Assassination     1.0
#
#    Wounded                   Target Summary  \
# 0      0.0             Julio Guzman     NaN
# 1      0.0  Nadine Chaval, daughter     NaN
# 2      0.0                 Employee     NaN
#
#                                 Group                  Target_type Weapon_type
# 0                              MANO-D  Private Citizens & Property     Unknown
# 1  23rd of September Communist League      Government (Diplomatic)     Unknown
# 2                             Unknown          Journalists & Media     Unknown

# %%
df=df[df['Country']=='India']
df=df[df['Year']>=2014]
idex_lvl1=df[(df['Year']==2014)&(df['Month']<5)].index
idex_lvl2=df[(df['Year']==2014)&(df['Month']==5)&(df['Day']<26)].index
df.drop(idex_lvl1,inplace=True)
df.drop(idex_lvl2,inplace=True)
attack_no=df.shape[0]

df=df[df['Group']!='Unknown']
group_data = df['Group'].describe().top
# group_data
print(attack_no,group_data)
# Out:
# 2057 Maoists
